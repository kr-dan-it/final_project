# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
model = joblib.load('iris_extended_model.joblib')

# %%
iris_t_type_1 = model.predict([[169, 1, 5, 2, 3, 1, 8, 70]])
iris_t_type_2 = model.predict([[119, 1, 4.9, 3.8, 1.2, 0.3, 5.18, 50.5]])

# %%
iris_t_type_1, iris_t_type_2
# Out:
# (array(['versicolor'], dtype=object), array(['setosa'], dtype=object))
